# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import pickle
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

from f_NVP import train_crealnvp_paper2022
# Out:
# /home/enjongoopee/.local/lib/python3.12/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
model_type = "hes"
validation_chunk_idxs = [15, 24, 78]
batch_size = 16384
scale_clip = 2.0
target_parameterization = "ut" # mt, ut

# %%
lr = 1e-5 # 논문 : [1e-5, 1e-5, 1e-6, 1e-6, 1e-6]
num_chunks = 94
val_every_chunks = 97
resume_path = f"result/nvp/{model_type}/cvae_{model_type}_{batch_size}_{lr}_{scale_clip}_{validation_chunk_idxs}_{target_parameterization}_chunk582.pt"
save_path = f"result/nvp/{model_type}/cvae_{model_type}_{batch_size}_{lr}_{scale_clip}_{validation_chunk_idxs}_{target_parameterization}_chunk676.pt"
nvp, nvp_ckpt = train_crealnvp_paper2022(
    device="cuda",
    model_type=model_type,
    target_pair="XT_MT",
    batch_size=batch_size,
    num_chunks=num_chunks,
    val_every_chunks=val_every_chunks,
    validation_chunk_idxs=validation_chunk_idxs,
    lr=lr,
    scale_clip=scale_clip,
    resume_path=resume_path,
    save_path=save_path,
    target_parameterization=target_parameterization,
)
# Out:
# device=cuda, model_type=hes, target_pair=XT_MIN, target_parameterization=ut, dim_eta=7
# chunk_dir=/mnt/d/heston_chunks_correction, eta_path=/mnt/d/heston_eta_basic.h5
# train_chunks=97, val_chunks=3
# rows/epoch=6,509,559,808, effective_rows/epoch=6,509,559,808, batch_size=16,384
# completed_epochs=6, completed_chunks=582, chunks_this_call=94, target_chunks=676
# val_every_chunks=97, tmp_save_every_chunks=10, memory_on_gpu=True
# BN pretraining first 5.0% = 325,477,991 rows
# run LR schedule=[1e-05]
# [GPU chunk loaded] heston_chunk_036.h5 | rows=67,108,864 | data=2.25 GiB | time=65.0s
# Chunk step   583 | epoch   7 chunk   1/97 | idx= 36 | NLL=1.468426 | epoch NLL=1.468426 | time=155.4s | GPU=3.18 GiB
# [GPU chunk loaded] heston_chunk_017.h5 | rows=67,108,864 | data=2.25 GiB | time=73.7s
# Chunk step   584 | epoch   7 chunk   2/97 | idx= 17 | NLL=1.454514 | epoch NLL=1.461470 | time=162.5s | GPU=3.18 GiB
# ...

# %%
lr = 1e-5 # 논문 : [1e-5, 1e-5, 1e-6, 1e-6, 1e-6]
num_chunks = 3
val_every_chunks = 1
resume_path = f"result/nvp/{model_type}/cvae_{model_type}_{batch_size}_{lr}_{scale_clip}_{validation_chunk_idxs}_{target_parameterization}_chunk676.pt"
save_path = f"result/nvp/{model_type}/cvae_{model_type}_{batch_size}_{lr}_{scale_clip}_{validation_chunk_idxs}_{target_parameterization}_chunk679.pt"
nvp, nvp_ckpt = train_crealnvp_paper2022(
    device="cuda",
    model_type=model_type,
    target_pair="XT_MT",
    batch_size=batch_size,
    num_chunks=num_chunks,
    val_every_chunks=val_every_chunks,
    validation_chunk_idxs=validation_chunk_idxs,
    lr=lr,
    scale_clip=scale_clip,
    resume_path=resume_path,
    save_path=save_path,
    target_parameterization=target_parameterization,
)
# Out:
# device=cuda, model_type=hes, target_pair=XT_MIN, target_parameterization=ut, dim_eta=7
# chunk_dir=/mnt/d/heston_chunks_correction, eta_path=/mnt/d/heston_eta_basic.h5
# train_chunks=97, val_chunks=3
# rows/epoch=6,509,559,808, effective_rows/epoch=6,509,559,808, batch_size=16,384
# completed_epochs=6, completed_chunks=676, chunks_this_call=3, target_chunks=679
# val_every_chunks=1, tmp_save_every_chunks=10, memory_on_gpu=True
# BN pretraining first 5.0% = 325,477,991 rows
# run LR schedule=[1e-05]
# [GPU chunk loaded] heston_chunk_082.h5 | rows=67,108,864 | data=2.25 GiB | time=70.0s
# Chunk step   677 | epoch   7 chunk  95/97 | idx= 82 | NLL=1.418649 | epoch NLL=1.412627 | time=162.3s | GPU=3.18 GiB
# [GPU chunk loaded] heston_chunk_015.h5 | rows=67,108,864 | data=2.25 GiB | time=62.7s
# [GPU chunk loaded] heston_chunk_024.h5 | rows=67,108,864 | data=2.25 GiB | time=61.9s
# [GPU chunk loaded] heston_chunk_078.h5 | rows=67,108,864 | data=2.25 GiB | time=62.8s
# ...

# %%
lr          = 1e-5 # 논문 : [1e-5, 1e-5, 1e-6, 1e-6, 1e-6]
l1          = 5
lr2         = 1e-6
l2          = 6
num_chunks = 94
val_every_chunks = 97
resume_path = f"result/nvp/{model_type}/cvae_{model_type}_{batch_size}_{lr}_{scale_clip}_{validation_chunk_idxs}_{target_parameterization}_chunk485.pt"
save_path = f"result/nvp/{model_type}/cvae_{model_type}_{batch_size}_{l1}-{lr}_{l2}-{lr2}_{scale_clip}_{validation_chunk_idxs}_{target_parameterization}_chunk579.pt"
nvp, nvp_ckpt = train_crealnvp_paper2022(
    device="cuda",
    model_type=model_type,
    target_pair="XT_MT",
    batch_size=batch_size,
    num_chunks=num_chunks,
    val_every_chunks=val_every_chunks,
    validation_chunk_idxs=validation_chunk_idxs,
    lr=lr2,
    scale_clip=scale_clip,
    resume_path=resume_path,
    save_path=save_path,
    target_parameterization=target_parameterization,
)
# Out:
# device=cuda, model_type=hes, target_pair=XT_MIN, target_parameterization=ut, dim_eta=7
# chunk_dir=/mnt/d/heston_chunks_correction, eta_path=/mnt/d/heston_eta_basic.h5
# train_chunks=97, val_chunks=3
# rows/epoch=6,509,559,808, effective_rows/epoch=6,509,559,808, batch_size=16,384
# completed_epochs=5, completed_chunks=485, chunks_this_call=94, target_chunks=579
# val_every_chunks=97, tmp_save_every_chunks=10, memory_on_gpu=True
# BN pretraining first 5.0% = 325,477,991 rows
# run LR schedule=[1e-06]
# [GPU chunk loaded] heston_chunk_077.h5 | rows=67,108,864 | data=2.25 GiB | time=40.3s

# %%
lr          = 1e-5 # 논문 : [1e-5, 1e-5, 1e-6, 1e-6, 1e-6]
l1          = 5
lr2         = 1e-6
l2          = 6
num_chunks = 3
val_every_chunks = 1
resume_path = f"result/nvp/{model_type}/cvae_{model_type}_{batch_size}_{l1}-{lr}_{l2}-{lr2}_{scale_clip}_{validation_chunk_idxs}_{target_parameterization}_chunk579.pt"
save_path = f"result/nvp/{model_type}/cvae_{model_type}_{batch_size}_{l1}-{lr}_{l2}-{lr2}_{scale_clip}_{validation_chunk_idxs}_{target_parameterization}_chunk582.pt"
nvp, nvp_ckpt = train_crealnvp_paper2022(
    device="cuda",
    model_type=model_type,
    target_pair="XT_MT",
    batch_size=batch_size,
    num_chunks=num_chunks,
    val_every_chunks=val_every_chunks,
    validation_chunk_idxs=validation_chunk_idxs,
    lr=lr2,
    scale_clip=scale_clip,
    resume_path=resume_path,
    save_path=save_path,
    target_parameterization=target_parameterization,
)

# %%
lr          = 1e-5 # 논문 : [1e-5, 1e-5, 1e-6, 1e-6, 1e-6]
l1          = 5
lr2         = 1e-6
l2          = 6
num_chunks = 94
val_every_chunks = 97
resume_path = f"result/nvp/{model_type}/cvae_{model_type}_{batch_size}_{l1}-{lr}_{l2}-{lr2}_{scale_clip}_{validation_chunk_idxs}_{target_parameterization}_chunk582.pt"
save_path = f"result/nvp/{model_type}/cvae_{model_type}_{batch_size}_{l1}-{lr}_{l2}-{lr2}_{scale_clip}_{validation_chunk_idxs}_{target_parameterization}_chunk676.pt"
nvp, nvp_ckpt = train_crealnvp_paper2022(
    device="cuda",
    model_type=model_type,
    target_pair="XT_MT",
    batch_size=batch_size,
    num_chunks=num_chunks,
    val_every_chunks=val_every_chunks,
    validation_chunk_idxs=validation_chunk_idxs,
    lr=lr2,
    scale_clip=scale_clip,
    resume_path=resume_path,
    save_path=save_path,
    target_parameterization=target_parameterization,
)

# %%
lr          = 1e-5 # 논문 : [1e-5, 1e-5, 1e-6, 1e-6, 1e-6]
l1          = 5
lr2         = 1e-6
l2          = 6
num_chunks = 3
val_every_chunks = 1
resume_path = f"result/nvp/{model_type}/cvae_{model_type}_{batch_size}_{l1}-{lr}_{l2}-{lr2}_{scale_clip}_{validation_chunk_idxs}_{target_parameterization}_chunk676.pt"
save_path = f"result/nvp/{model_type}/cvae_{model_type}_{batch_size}_{l1}-{lr}_{l2}-{lr2}_{scale_clip}_{validation_chunk_idxs}_{target_parameterization}_chunk679.pt"
nvp, nvp_ckpt = train_crealnvp_paper2022(
    device="cuda",
    model_type=model_type,
    target_pair="XT_MT",
    batch_size=batch_size,
    num_chunks=num_chunks,
    val_every_chunks=val_every_chunks,
    validation_chunk_idxs=validation_chunk_idxs,
    lr=lr2,
    scale_clip=scale_clip,
    resume_path=resume_path,
    save_path=save_path,
    target_parameterization=target_parameterization,
)

# %%
lr          = 1e-5 # 논문 : [1e-5, 1e-5, 1e-6, 1e-6, 1e-6]
l1          = 5
lr2         = 1e-6
l2          = 6
num_chunks = 94
val_every_chunks = 97
resume_path = f"result/nvp/{model_type}/cvae_{model_type}_{batch_size}_{l1}-{lr}_{l2}-{lr2}_{scale_clip}_{validation_chunk_idxs}_{target_parameterization}_chunk679.pt"
save_path = f"result/nvp/{model_type}/cvae_{model_type}_{batch_size}_{l1}-{lr}_{l2}-{lr2}_{scale_clip}_{validation_chunk_idxs}_{target_parameterization}_chunk773.pt"
nvp, nvp_ckpt = train_crealnvp_paper2022(
    device="cuda",
    model_type=model_type,
    target_pair="XT_MT",
    batch_size=batch_size,
    num_chunks=num_chunks,
    val_every_chunks=val_every_chunks,
    validation_chunk_idxs=validation_chunk_idxs,
    lr=lr2,
    scale_clip=scale_clip,
    resume_path=resume_path,
    save_path=save_path,
    target_parameterization=target_parameterization,
)

# %%
lr          = 1e-5 # 논문 : [1e-5, 1e-5, 1e-6, 1e-6, 1e-6]
l1          = 5
lr2         = 1e-6
l2          = 6
num_chunks = 3
val_every_chunks = 1
resume_path = f"result/nvp/{model_type}/cvae_{model_type}_{batch_size}_{l1}-{lr}_{l2}-{lr2}_{scale_clip}_{validation_chunk_idxs}_{target_parameterization}_chunk773.pt"
save_path = f"result/nvp/{model_type}/cvae_{model_type}_{batch_size}_{l1}-{lr}_{l2}-{lr2}_{scale_clip}_{validation_chunk_idxs}_{target_parameterization}_chunk776.pt"
nvp, nvp_ckpt = train_crealnvp_paper2022(
    device="cuda",
    model_type=model_type,
    target_pair="XT_MT",
    batch_size=batch_size,
    num_chunks=num_chunks,
    val_every_chunks=val_every_chunks,
    validation_chunk_idxs=validation_chunk_idxs,
    lr=lr2,
    scale_clip=scale_clip,
    resume_path=resume_path,
    save_path=save_path,
    target_parameterization=target_parameterization,
)

# %% [markdown]
# # result

# %%
from pathlib import Path
from f_NVP import (
    load_crealnvp_checkpoint,
    price_current_options,
    sample_crealnvp,
)
model_type = "hes"
validation_chunk_idxs = [15, 24, 78]
batch_size = 16384
scale_clip = 5.0
lr          = 1e-5 # 논문 : [1e-5, 1e-5, 1e-6, 1e-6, 1e-6]
l1          = 2
lr2         = 1e-6
l2          = 3
num_chunks = 388
save_path = f"result/nvp/{model_type}/cvae_{model_type}_{batch_size}_{lr}_{scale_clip}_{validation_chunk_idxs}_chunk{num_chunks}.pt"
#save_path = f"result/nvp/{model_type}/cvae_{model_type}_{batch_size}_{l1}-{lr}_{l2}-{lr2}_{scale_clip}_{validation_chunk_idxs}_chunk{num_chunks}.pt"

nvp, nvp_ckpt = load_crealnvp_checkpoint(
    save_path,
    device="cuda",
)

nvp_result_base_path = str(Path(save_path).with_suffix(""))

# %% [markdown]
# # loss history

# %%
window = 97
epoch = 97

chunk_history = nvp_ckpt["chunk_loss_history"]

chunk_nll = np.asarray(chunk_history["nll"], dtype=float,)

global_chunks = np.asarray(
    chunk_history.get(
        "global_chunk",
        np.arange(1, len(chunk_nll) + 1),
    ),
    dtype=int,
)

# 이동평균
moving_average = np.convolve(chunk_nll, np.ones(window) / window, mode="valid",)
moving_average_chunks = global_chunks[window - 1:]

# Chunk 단위 validation history
validation_history = nvp_ckpt.get("validation_history", {})

validation_chunks = np.asarray(validation_history.get("global_chunk", []), dtype=int,)

validation_nll = np.asarray(validation_history.get("nll", []),dtype=float,)


# Plot
plt.figure(figsize=(12, 5))
plt.plot(
    global_chunks,
    chunk_nll,
    color="steelblue",
    linewidth=1,
    alpha=0.35,
    label="Chunk NLL",
)

# Window 이동평균
plt.plot(
    moving_average_chunks,
    moving_average,
    color="navy",
    linewidth=2,
    label=f"Moving average (window={window})",
)

# Chunk 단위 Validation NLL
if len(validation_nll) > 0:
    plt.plot(
        validation_chunks,
        validation_nll,
        color="darkorange",
        marker="o",
        linewidth=1.5,
        markersize=5,
        label="Validation NLL",
    )

plt.xlabel("Global Chunk")
plt.ylabel("Negative log-likelihood")
plt.ylim(-1.6, -1.2)
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(epoch))
plt.title("CRealNVP Chunk Loss History")
plt.grid(alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # inference result

# %%
S0 = 1.0
K = 1.0
B = 0.8
r = 0.03
sigma = np.sqrt(0.05)
T = 1.5

if model_type in ("hes", "hes_clip"):
    test_etas = [0.03, 2.0, 0.05, 0.5, -0.7, 0.05, 1.5]
else:
    test_etas = [0.03, np.sqrt(0.05), 1.5]

eta_raw = np.asarray(test_etas, dtype=np.float32)

option_keys = ["van_call", "van_put", "barr_call", "barr_put"]
n_list = [1_000, 10_000, 100_000]
n_repeats = 50
results_by_option = {key: {n: [] for n in n_list} for key in option_keys}

for n in n_list:
    for repeat_idx in range(n_repeats):
        prices = price_current_options(
            nvp, nvp_ckpt, eta_raw, S0=S0, K=K, B=B, r=r, T=T,
            n_samples=n, antithetic=False, seed=1234 + repeat_idx,
        )

        for key in option_keys:
            results_by_option[key][n].append(prices[key])

for key in option_keys:
    result_path = f"{nvp_result_base_path}_{key}.pkl"

    with open(result_path, "wb") as file:
        pickle.dump(results_by_option[key], file)

    print(f"saved: {result_path}")
# Out:
# saved: result/nvp/hes/cvae_hes_16384_2-1e-05_3-1e-06_5.0_[15, 24, 78]_chunk291_van_call.pkl
# saved: result/nvp/hes/cvae_hes_16384_2-1e-05_3-1e-06_5.0_[15, 24, 78]_chunk291_van_put.pkl
# saved: result/nvp/hes/cvae_hes_16384_2-1e-05_3-1e-06_5.0_[15, 24, 78]_chunk291_barr_call.pkl
# saved: result/nvp/hes/cvae_hes_16384_2-1e-05_3-1e-06_5.0_[15, 24, 78]_chunk291_barr_put.pkl

# %%
# CVAE inference result graphs for four option payoffs
n_list = [1000, 10000, 100000]
option_keys = ["van_call", "van_put", "barr_call", "barr_put"]
option_labels = {
    "van_call": "Vanilla Call",
    "van_put": "Vanilla Put",
    "barr_call": "Barrier Call",
    "barr_put": "Barrier Put",
}
bench_prices = {
    "hes": {
        "van_call": 0.124491,
        "van_put": 0.080488,
        "barr_call": 0.115733,
        "barr_put": 0.005170,
    },
    "bs": {
        "van_call": 0.129944,
        "van_put": 0.085942,
        "barr_call": 0.123493,
        "barr_put": 0.009535,
    },
    "hes_clip": {
        "van_call": 0.124491,
        "van_put": 0.080488,
        "barr_call": 0.115733,
        "barr_put": 0.005170,
    },
    "bs_clip": {
        "van_call": 0.129944,
        "van_put": 0.085942,
        "barr_call": 0.123493,
        "barr_put": 0.009535,
    },
}
fig, axes = plt.subplots(2, 2, figsize=(7, 6), sharex=True)
axes = axes.ravel()

for ax, key in zip(axes, option_keys):
    with open(f"{nvp_result_base_path}_{key}.pkl", "rb") as f:
        results = pickle.load(f)

    means = np.array([np.mean(results[n]) for n in n_list])
    stds = np.array([np.std(results[n]) for n in n_list])
    ci = 1.96 * stds
    bench = bench_prices[model_type][key]

    print(option_labels[key])
    for n, mean, std, err in zip(n_list, means, stds, ci):
        rel_err = (mean - bench) / (bench) * 100
        print(f"n={n:6d} | mean={mean:.8f} | std ={std:.8f} |95% CI=±{err:.8f} | error={rel_err:+.2f}%")
    print()

    ax.axhline(bench, color="red", linestyle='--', linewidth=1.5, label="FDM")
    ax.errorbar(
        range(len(n_list)), means,
        yerr=ci, fmt="o-", color="steelblue", capsize=5, label="CVAE (95% CI)",
    )
    ax.set_xticks(range(len(n_list)))
    ax.set_xticklabels(["1K", "10K", "100K"])
    ax.set_title(option_labels[key])
    ax.set_xlabel("Number of CVAE samples")
    ax.set_ylabel("Option price")
    ax.grid(True, alpha=0.3)
    ax.legend()

fig.suptitle(nvp_result_base_path)
plt.tight_layout()
plt.show()
# Out:
# Vanilla Call
# n=  1000 | mean=0.12469692 | std =0.00448544 |95% CI=±0.00879147 | error=+0.17%
# n= 10000 | mean=0.12427591 | std =0.00147287 |95% CI=±0.00288683 | error=-0.17%
# n=100000 | mean=0.12378858 | std =0.00042602 |95% CI=±0.00083499 | error=-0.56%
#
# Vanilla Put
# n=  1000 | mean=0.08200471 | std =0.00430465 |95% CI=±0.00843711 | error=+1.88%
# n= 10000 | mean=0.08156679 | std =0.00130664 |95% CI=±0.00256102 | error=+1.34%
# n=100000 | mean=0.08150151 | std =0.00042420 |95% CI=±0.00083143 | error=+1.26%
#
# Barrier Call
# n=  1000 | mean=0.11656374 | std =0.00451693 |95% CI=±0.00885318 | error=+0.72%
# n= 10000 | mean=0.11594643 | std =0.00147842 |95% CI=±0.00289771 | error=+0.18%
# n=100000 | mean=0.11540964 | std =0.00042745 |95% CI=±0.00083781 | error=-0.28%
#
# Barrier Put
# n=  1000 | mean=0.00518311 | std =0.00051617 |95% CI=±0.00101170 | error=+0.25%
# n= 10000 | mean=0.00529976 | std =0.00024182 |95% CI=±0.00047396 | error=+2.51%
# ...

# %% [markdown]
# # robust

# %%
# CVAE robust 셀과 같은 기준으로 NVP 결과만 새로 계산
from pathlib import Path
import pandas as pd
import torch

from f_NVP import price_current_options
from f_robust import (
    ROBUSTNESS_VARIABLES_MAIN,
    run_robustness,
    save_robustness_results,
)

# f_robust의 eta 형식: (S0, K, 모델 파라미터들...)
BS_eta = (1.0, 1.0, 0.03, np.sqrt(0.05), 1.5)
Hes_eta = (1.0, 1.0, 0.03, 2.0, 0.05, 0.5, -0.7, 0.05, 1.5)
robust_barrier = 0.8
n_samples_list = (1_000, 10_000, 100_000)
nvp_repeats = 50
valid_resample = True
mt_corr = False


class NVPPriceAdapter:
    # f_robust가 기대하는 total_pricing 인터페이스를 NVP에 연결한다.
    def __init__(self, model, checkpoint, seed=1234):
        self.model = model
        self.checkpoint = checkpoint
        self.seed = seed
        self.call_count = 0

        eta_min = checkpoint["eta_min"]
        eta_max = checkpoint["eta_max"]
        if torch.is_tensor(eta_min):
            eta_min = eta_min.detach().cpu().numpy()
        if torch.is_tensor(eta_max):
            eta_max = eta_max.detach().cpu().numpy()
        self.eta_min = np.asarray(eta_min, dtype=np.float32)
        self.eta_max = np.asarray(eta_max, dtype=np.float32)

    def total_pricing(self, eta_scaled, B, K, r, T, n_samples, validate_samples=True, valid_resample=True, mt_corr=False):
        if torch.is_tensor(eta_scaled):
            eta_scaled = eta_scaled.detach().cpu().numpy()
        eta_scaled = np.asarray(eta_scaled, dtype=np.float32)

        # f_robust의 정규화를 정확히 역변환한다.
        eta_raw = eta_scaled * (self.eta_max - self.eta_min + 1e-8) + self.eta_min
        eta_raw = np.asarray(eta_raw, dtype=np.float32)
        eta_raw[0] = float(r)
        eta_raw[-1] = float(T)

        # invalid 재추출에 쓰이는 내부 seed와 다음 반복의 seed가 겹치지 않게 간격을 둔다.
        current_seed = self.seed + 1_000 * self.call_count
        self.call_count += 1
        return price_current_options(
            self.model,
            self.checkpoint,
            eta_raw,
            S0=1.0,
            K=float(K),
            B=float(B),
            r=float(r),
            T=float(T),
            n_samples=int(n_samples),
            antithetic=False,
            seed=current_seed,
            validate_samples=validate_samples,
            valid_resample=valid_resample,
            mt_corr=mt_corr,
        )


# Closed/FDM/MC 기준값은 CVAE robust 계산 결과를 그대로 재사용한다.
if model_type in ("bs", "bs_clip"):
    sigma_upper = ROBUSTNESS_VARIABLES_MAIN["bs"]["sigma"][1]
    if np.isclose(sigma_upper, 0.8):
        old_robust_path = Path(
            "result/robust/cvae_bs_2_128_4096_None_0.0001_1_"
            "[15, 24, 78]_chunk1261_robustness_compat.pkl"
        )
        robust_suffix = "robustness"
    elif np.isclose(sigma_upper, 0.75):
        old_robust_path = Path(
            "result/robust/cvae_bs_normal_weight_2_1024_16384_None_"
            "11-2e-05_12-2e-06_1_barrier_put_0.45_"
            "[15, 24, 78]_chunk1358_fine_robustness2_compat.pkl"
        )
        robust_suffix = "robustness2"
    else:
        raise ValueError(f"재사용할 BS robust 기준 파일이 없습니다: sigma={sigma_upper}")
else:
    old_robust_path = Path(
        "result/robust/cvae_hes_2_128_4096_None_0.0001_1_"
        "[15, 24, 78]_chunk776_robustness_compat.pkl"
    )
    robust_suffix = "robustness"

if not old_robust_path.is_file():
    raise FileNotFoundError(f"robust 기준 파일을 찾을 수 없습니다: {old_robust_path}")

old_results = pd.read_pickle(old_robust_path).copy()
old_results["model"] = model_type

nvp_adapter = NVPPriceAdapter(nvp, nvp_ckpt, seed=1234)
adapter_results = run_robustness(
    BS_eta,
    Hes_eta,
    ROBUSTNESS_VARIABLES_MAIN,
    models=(model_type,),
    barrier=robust_barrier,
    barr_types=("van", "barr"),
    option_types=("call", "put"),
    run_fdm=False,
    run_mc=False,
    n_samples_list=n_samples_list,
    mc_repeats=50,
    mc_dt=0.001,
    cvae=nvp_adapter,
    checkpoint=nvp_ckpt,
    device=next(nvp.parameters()).device,
    cvae_repeats=nvp_repeats,
    validate_samples=True,
    valid_resample=valid_resample,
    mt_corr=mt_corr,
)

key_cols = ["model", "variable", "value", "barr_type", "option_type"]
generator_cols = [
    "cvae",
    "cvae_std",
    "cvae_seconds",
    "cvae_results",
    "cvae_seconds_by_n",
    "sampling_diagnostics_by_n",
    "used_sample_count",
    "discarded_sample_pct",
    "regenerated_sample_pct",
    "mt_corrected_sample_pct",
]

# f_robust 내부의 cvae_* 칸을 NVP 저장 공간으로 사용한다.
# 표시 셀에서는 nvp_* 이름으로 바꿔서 보여준다.
adapter_values = adapter_results[key_cols + generator_cols + ["error"]].rename(
    columns={"error": "nvp_error"}
)
old_attrs = dict(old_results.attrs)
new_results = old_results.drop(
    columns=[
        col for col in old_results.columns
        if col.startswith("cvae") or col in generator_cols
    ],
    errors="ignore",
).merge(adapter_values, on=key_cols, how="left")


def combine_robust_errors(row):
    messages = []
    for value in (row.get("error"), row.get("nvp_error")):
        if pd.notna(value) and str(value).strip():
            messages.append(str(value).replace("cvae=", "nvp="))
    return "; ".join(dict.fromkeys(messages)) or None


new_results["error"] = new_results.apply(combine_robust_errors, axis=1)
new_results = new_results.drop(columns="nvp_error")

# Heston도 재사용한 FDM reference를 기준으로 NVP 오차를 다시 계산한다.
nvp_difference = new_results["cvae"] - new_results["reference"]
new_results["cvae_abs_error"] = nvp_difference.abs()
new_results["cvae_rel_error_pct"] = np.where(
    new_results["reference"].abs() > 1e-12,
    nvp_difference.abs() / new_results["reference"].abs() * 100.0,
    np.nan,
)
new_results.attrs.update(old_attrs)
new_results.attrs.update(adapter_results.attrs)
new_results.attrs["generator"] = "NVP"
new_results.attrs["nvp_repeats"] = nvp_repeats

robust_stem = f"{Path(save_path).stem}_nvp_{robust_suffix}"
pickle_path, csv_path = save_robustness_results(
    new_results,
    output_dir="result/robust",
    stem=robust_stem,
)

# 저장되는 요약 CSV의 열 이름도 NVP로 표시한다.
saved_summary = pd.read_csv(csv_path)
saved_summary = saved_summary.rename(columns={
    col: col.replace("cvae", "nvp", 1)
    for col in saved_summary.columns
    if col.startswith("cvae")
})
saved_summary.to_csv(csv_path, index=False)

print("raw results:", pickle_path)
print("summary    :", csv_path)
# Out:
# [001] hes | r=0.0025 | van call
# [002] hes | r=0.0025 | van put
# [003] hes | r=0.0025 | barr call
# [004] hes | r=0.0025 | barr put
# [005] hes | r=0.0975 | van call
# [006] hes | r=0.0975 | van put
# [007] hes | r=0.0975 | barr call
# [008] hes | r=0.0975 | barr put
# [009] hes | kappa=1.3 | van call
# [010] hes | kappa=1.3 | van put
# [011] hes | kappa=1.3 | barr call
# [012] hes | kappa=1.3 | barr put
# [013] hes | kappa=4.5 | van call
# [014] hes | kappa=4.5 | van put
# [015] hes | kappa=4.5 | barr call
# [016] hes | kappa=4.5 | barr put
# [017] hes | theta=0.035 | van call
# [018] hes | theta=0.035 | van put
# [019] hes | theta=0.035 | barr call
# [020] hes | theta=0.035 | barr put
# [021] hes | theta=0.15 | van call
# [022] hes | theta=0.15 | van put
# [023] hes | theta=0.15 | barr call
# [024] hes | theta=0.15 | barr put
# [025] hes | xi=0.15 | van call
# [026] hes | xi=0.15 | van put
# [027] hes | xi=0.15 | barr call
# [028] hes | xi=0.15 | barr put
# ...

# %%
# 저장된 NVP robust 결과 확인
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from f_robust import ROBUSTNESS_VARIABLES_MAIN, build_sampling_summary

if model_type in ("bs", "bs_clip") and np.isclose(
    ROBUSTNESS_VARIABLES_MAIN["bs"]["sigma"][1], 0.75
):
    robust_suffix = "robustness2"
else:
    robust_suffix = "robustness"

robust_stem = f"{Path(save_path).stem}_nvp_{robust_suffix}"
pkl_path = Path("result/robust") / f"{robust_stem}.pkl"
robust_results = pd.read_pickle(pkl_path)

if "model" in robust_results.columns and model_type not in set(
    robust_results["model"].astype(str)
) and model_type in {"bs_clip", "hes_clip"}:
    robust_results = robust_results.copy()
    robust_results["model"] = model_type

sampling_summary = build_sampling_summary(robust_results)
option_keys = ("van_call", "van_put", "barr_call", "barr_put")
option_labels = {
    "van_call": "Vanilla Call",
    "van_put": "Vanilla Put",
    "barr_call": "Barrier Call",
    "barr_put": "Barrier Put",
}

for variable, values in ROBUSTNESS_VARIABLES_MAIN[model_type].items():
    for value in values:
        print(f"\n{model_type} | {variable}={value:g}")
        case_summary = sampling_summary[
            sampling_summary["model"].eq(model_type)
            & sampling_summary["variable"].eq(variable)
            & np.isclose(sampling_summary["value"], value)
        ]

        display_table = case_summary[[
            "barr_type",
            "option_type",
            "n_samples",
            "reference",
            "mc_mean",
            "mc_std",
            "mc_rel_error_pct",
            "cvae_mean",
            "cvae_std",
            "cvae_rel_error_pct",
        ]].rename(columns={
            "cvae_mean": "nvp_mean",
            "cvae_std": "nvp_std",
            "cvae_rel_error_pct": "nvp_rel_error_pct",
        })
        display(display_table)

        # plot_sampling_comparison과 같은 구성으로 NVP 라벨을 사용한다.
        fig, axes = plt.subplots(2, 2, figsize=(9, 7), sharex=True)
        axes = axes.ravel()
        x_offset = 0.04

        for ax, option_key in zip(axes, option_keys):
            barr_type, option_type = option_key.split("_", 1)
            option_data = case_summary[
                case_summary["barr_type"].eq(barr_type)
                & case_summary["option_type"].eq(option_type)
            ].sort_values("n_samples")
            n_samples = option_data["n_samples"].to_numpy(dtype=int)
            x_positions = np.arange(len(n_samples))

            if option_data["mc_mean"].notna().any():
                ax.errorbar(
                    x_positions - x_offset,
                    option_data["mc_mean"],
                    yerr=1.96 * option_data["mc_std"],
                    fmt="o-",
                    color="grey",
                    capsize=5,
                    label="MC (95% range)",
                )
            if option_data["cvae_mean"].notna().any():
                ax.errorbar(
                    x_positions + x_offset,
                    option_data["cvae_mean"],
                    yerr=1.96 * option_data["cvae_std"],
                    fmt="o-",
                    color="steelblue",
                    capsize=5,
                    label="NVP (95% range)",
                )

            reference = float(option_data["reference"].iloc[0])
            reference_label = "Closed" if model_type in ("bs", "bs_clip") else "FDM"
            ax.axhline(
                reference,
                color="red",
                linestyle="--",
                linewidth=1.5,
                label=reference_label,
            )
            ax.set_xticks(x_positions)
            ax.set_xticklabels([
                f"{n // 1000}K" if n >= 1000 and n % 1000 == 0 else f"{n:,}"
                for n in n_samples
            ])
            ax.tick_params(axis="x", labelbottom=True)
            ax.set_title(option_labels[option_key])
            ax.set_xlabel("Number of samples")
            ax.set_ylabel("Option price")
            ax.grid(True, alpha=0.3)
            ax.legend()

        fig_name = "BS" if model_type in ("bs", "bs_clip") else "Heston"
        fig.suptitle(f"{fig_name} NVP robustness | {variable}={value:g}")
        plt.tight_layout()
        plt.show()

failed_cases = robust_results[robust_results["error"].notna()]
if not failed_cases.empty:
    print("\n계산 실패 항목")
    display(failed_cases[[
        "model", "variable", "value", "barr_type", "option_type", "error"
    ]])
# Out:
# hes | r=0.0025
#    barr_type option_type  n_samples  reference   mc_mean    mc_std  \
# 0        van        call       1000   0.101699  0.101504  0.005288
# 1        van        call      10000   0.101699  0.101265  0.001436
# 2        van        call     100000   0.101699  0.101535  0.000422
# 3        van         put       1000   0.097956  0.096966  0.004430
# 4        van         put      10000   0.097956  0.098251  0.001801
# 5        van         put     100000   0.097956  0.097814  0.000462
# 6       barr        call       1000   0.094438  0.094304  0.005255
# 7       barr        call      10000   0.094438  0.094084  0.001416
# 8       barr        call     100000   0.094438  0.094286  0.000422
# 9       barr         put       1000   0.006606  0.006605  0.000758
# 10      barr         put      10000   0.006606  0.006593  0.000258
# 11      barr         put     100000   0.006606  0.006618  0.000081
#
#     mc_rel_error_pct  nvp_mean   nvp_std  nvp_rel_error_pct
# ...
