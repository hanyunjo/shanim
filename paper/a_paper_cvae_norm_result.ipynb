# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import os
import time
import pickle
import matplotlib.pyplot as plt
from scipy.stats import norm
from matplotlib.ticker import MaxNLocator

from e_1_run_cvae_norm import * 
from e_2_CVAE_norm import *

# global var
S0 = 1.0
K = 1.0
r = 0.03
sigma = np.sqrt(0.05)
T = 1.5
BS_eta = (S0, K, r, sigma, T)
# S0, K, r, kappa, theta, xi, rho, Y0, T = Hes_eta
Hes_eta = (S0, K, r, 2, 0.05, 0.5, -0.7, 0.05, T)

B = 0.8 # down-and-out must B < S0 and B < K
model_type = 'bs' # hes or bs
barr_type = 'barr' # van or barr
opt_type = 'put' # call or put
chunk_dir = f"/mnt/d/bs_chunks_correction/" if model_type == 'bs' else f"/mnt/d/hes_chunks_correction/"
eta_path = "/mnt/d/bs_eta_basic.h5" if model_type == 'bs' else "/mnt/d/hes_eta_basic.h5"

if not((B < S0) & (B < K)):
    raise ValueError("down-and-out : B should be smaller than S0 and K")

if not(opt_type == 'call' or  opt_type == 'put'):
    raise ValueError("option_type must be 'call' or 'put'")

if not(barr_type == 'van' or  barr_type == 'barr'):
    raise ValueError("barr_type must be 'van' or 'barr'")

if not(model_type == 'hes' or  model_type == 'bs'):
    raise ValueError("model_type must be 'hes' or 'bs'")

if not(torch.cuda.is_available()):
    raise ValueError("CUDA is not available")
device = torch.device("cuda")

bs_stats = {
    "x_mean": -0.1045446063,
    "x_std": 0.6455563393,
    "m_mean": -0.4579059199,
    "m_std": 0.5553496410
}

if model_type == 'hes':
    if barr_type == 'barr':
        if opt_type == 'call':
            bench_price = 0.115733
        else: # put
            bench_price = 0.005170
    else: # van
        if opt_type == 'call':
            bench_price = 0.124491
        else: # put
            bench_price = 0.080488

elif model_type == 'bs':
    if barr_type == 'barr':
        if opt_type == 'call':
            bench_price = 0.123493
        else: # put
            bench_price = 0.009535
    else: # van
        if opt_type == 'call':
            bench_price = 0.129944
        else: # put
            bench_price = 0.085942
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# CVAE training settings
dim_z       = 8 # 12
hidden_dims = [128, 128, 64] # [128, 128, 64], [256, 256, 128], [512, 512, 256]
batch_size  = 4096 # 1024, 2048, 4096, 8192
bn_chunks   = None # None or num
use_bn      = True if bn_chunks is not None else False
lr          = 0.001 # 0.001,0.0003, 0.0005
beta        = 1
warmup_chunks = None # None or num
num_chunks  = 100
resume_path = None # or None 이어서 학습하고 싶을 때
save_path   = f"result/cvae_xm_norm/{model_type}/cvae_{model_type}_{dim_z}_{hidden_dims[0]}\
_{batch_size}_{bn_chunks}_{lr}_{beta}_{warmup_chunks}_chunk{num_chunks}.pt"

if model_type == 'hes':
    test_etas = [0.03, 2.0,  0.05, 0.5, -0.7, 0.05, 1.5]
    eta_keys  = ['r', 'lambda', 'v_bar', 'xi', 'rho', 'Y0', 'T']
else: # model_type = 'bs'
    test_etas = [r, sigma, T]
    eta_keys  = ['r', 'sigma', 'T']

# %%
save_path = f"result/cvae_xm_norm/{model_type}/cvae_{model_type}_{dim_z}_{hidden_dims[0]}\
_{batch_size}_{bn_chunks}_{lr}_{beta}_{warmup_chunks}_chunk{num_chunks}.pt"
ckpt = torch.load(save_path, map_location=device, weights_only=False)
chunk_loss_history = ckpt.get("chunk_loss_history", None)

chunks = range(1, len(chunk_loss_history["total_loss"]) + 1)
plt.plot(chunks, chunk_loss_history["total_loss"], label="Total", color="green", linewidth=2)
plt.plot(chunks, chunk_loss_history["recon_loss"], label="Recon", color="blue", linestyle="--", linewidth=2)
plt.plot(chunks,  chunk_loss_history["KL_loss"], label="KL", color="orange", linewidth=2)
plt.xlabel('Chunk')
plt.ylabel('Loss')
plt.xticks(chunks)
ax = plt.gca()
ax.xaxis.set_major_locator(MaxNLocator(integer=True))
plt.legend()
plt.show()

# %%
save_path = f"result/cvae_xm_norm/{model_type}/cvae_{model_type}_{dim_z}_{hidden_dims[0]}\
_{batch_size}_{bn_chunks}_{lr}_{beta}_{warmup_chunks}_chunk{num_chunks}.pt"
ckpt = torch.load(save_path, map_location=device, weights_only=False)
chunk_loss_history = ckpt.get("chunk_loss_history", None)
chunk_indices = ckpt["chunk_loss_history"]["chunk_idx"]

for i in range(len(chunk_loss_history["total_loss"])):
    print(f"Idx : {chunk_indices[i]}, Total Loss: {chunk_loss_history['total_loss'][i]:.4f}, Recon Loss: {chunk_loss_history['recon_loss'][i]:.4f}, KL Loss: {chunk_loss_history['KL_loss'][i]:.4f}")
# Out:
# Idx : 48, Total Loss: 1.3512, Recon Loss: -1.6279, KL Loss: 2.9791
# Idx : 8, Total Loss: 0.4243, Recon Loss: -2.1843, KL Loss: 2.6085
# Idx : 16, Total Loss: 0.4117, Recon Loss: -2.1647, KL Loss: 2.5765
# Idx : 81, Total Loss: 0.3997, Recon Loss: -2.2740, KL Loss: 2.6737
# Idx : 6, Total Loss: 0.3779, Recon Loss: -2.3043, KL Loss: 2.6823
# Idx : 99, Total Loss: 1.2480, Recon Loss: -2.2319, KL Loss: 3.4800
# Idx : 38, Total Loss: 1.2406, Recon Loss: -2.3707, KL Loss: 3.6112
# Idx : 5, Total Loss: 0.3915, Recon Loss: -2.4354, KL Loss: 2.8269
# Idx : 55, Total Loss: 0.3661, Recon Loss: -2.4094, KL Loss: 2.7755
# Idx : 34, Total Loss: 0.3648, Recon Loss: -2.4473, KL Loss: 2.8121
# Idx : 20, Total Loss: 0.3690, Recon Loss: -2.4776, KL Loss: 2.8466
# Idx : 67, Total Loss: 0.5433, Recon Loss: -2.4891, KL Loss: 3.0323
# Idx : 56, Total Loss: 0.3690, Recon Loss: -2.4921, KL Loss: 2.8611
# Idx : 85, Total Loss: 0.3719, Recon Loss: -2.4823, KL Loss: 2.8542
# Idx : 87, Total Loss: 0.5137, Recon Loss: -2.5119, KL Loss: 3.0256
# Idx : 17, Total Loss: 0.5167, Recon Loss: -2.5273, KL Loss: 3.0440
# Idx : 60, Total Loss: 0.3625, Recon Loss: -2.5344, KL Loss: 2.8969
# Idx : 43, Total Loss: 0.3464, Recon Loss: -2.5593, KL Loss: 2.9057
# Idx : 19, Total Loss: 1.2460, Recon Loss: -2.4516, KL Loss: 3.6977
# Idx : 80, Total Loss: 0.3646, Recon Loss: -2.6630, KL Loss: 3.0276
# Idx : 45, Total Loss: 0.3540, Recon Loss: -2.5755, KL Loss: 2.9295
# Idx : 14, Total Loss: 0.3526, Recon Loss: -2.5934, KL Loss: 2.9461
# Idx : 62, Total Loss: 0.3553, Recon Loss: -2.6096, KL Loss: 2.9650
# Idx : 70, Total Loss: 0.3450, Recon Loss: -2.6576, KL Loss: 3.0026
# Idx : 75, Total Loss: 0.3521, Recon Loss: -2.6173, KL Loss: 2.9694
# Idx : 94, Total Loss: 0.3425, Recon Loss: -2.7042, KL Loss: 3.0467
# Idx : 54, Total Loss: 0.3547, Recon Loss: -2.6591, KL Loss: 3.0137
# Idx : 47, Total Loss: 0.5078, Recon Loss: -2.5880, KL Loss: 3.0958
# Idx : 84, Total Loss: 0.3632, Recon Loss: -2.6299, KL Loss: 2.9931
# Idx : 23, Total Loss: 0.3444, Recon Loss: -2.6557, KL Loss: 3.0002
# Idx : 30, Total Loss: 0.3594, Recon Loss: -2.6478, KL Loss: 3.0072
# Idx : 29, Total Loss: 1.2296, Recon Loss: -2.5499, KL Loss: 3.7795
# Idx : 79, Total Loss: 1.2244, Recon Loss: -2.6359, KL Loss: 3.8603
# Idx : 44, Total Loss: 0.3553, Recon Loss: -2.6773, KL Loss: 3.0326
# Idx : 71, Total Loss: 0.3631, Recon Loss: -2.6762, KL Loss: 3.0392
# Idx : 66, Total Loss: 0.3173, Recon Loss: -2.7249, KL Loss: 3.0421
# Idx : 28, Total Loss: 1.2290, Recon Loss: -2.5614, KL Loss: 3.7904
# Idx : 61, Total Loss: 0.3516, Recon Loss: -2.7048, KL Loss: 3.0564
# Idx : 15, Total Loss: 0.3476, Recon Loss: -2.6852, KL Loss: 3.0328
# Idx : 39, Total Loss: 1.2283, Recon Loss: -2.5789, KL Loss: 3.8072
# Idx : 63, Total Loss: 0.3452, Recon Loss: -2.7007, KL Loss: 3.0459
# Idx : 73, Total Loss: 0.3450, Recon Loss: -2.7363, KL Loss: 3.0813
# Idx : 52, Total Loss: 0.3402, Recon Loss: -2.7438, KL Loss: 3.0840
# Idx : 27, Total Loss: 0.5296, Recon Loss: -2.6328, KL Loss: 3.1624
# Idx : 3, Total Loss: 0.3367, Recon Loss: -2.6901, KL Loss: 3.0268
# Idx : 68, Total Loss: 1.2298, Recon Loss: -2.5958, KL Loss: 3.8256
# Idx : 35, Total Loss: 0.3274, Recon Loss: -2.7313, KL Loss: 3.0588
# Idx : 21, Total Loss: 0.3445, Recon Loss: -2.7515, KL Loss: 3.0960
# Idx : 7, Total Loss: 0.3485, Recon Loss: -2.7713, KL Loss: 3.1198
# Idx : 65, Total Loss: 0.3425, Recon Loss: -2.7342, KL Loss: 3.0767
# Idx : 22, Total Loss: 0.3370, Recon Loss: -2.7428, KL Loss: 3.0797
# Idx : 31, Total Loss: 0.3451, Recon Loss: -2.8333, KL Loss: 3.1784
# Idx : 64, Total Loss: 0.3411, Recon Loss: -2.6945, KL Loss: 3.0356
# Idx : 13, Total Loss: 0.3273, Recon Loss: -2.8143, KL Loss: 3.1415
# Idx : 88, Total Loss: 1.2402, Recon Loss: -2.5789, KL Loss: 3.8191
# Idx : 98, Total Loss: 1.2241, Recon Loss: -2.7168, KL Loss: 3.9409
# Idx : 24, Total Loss: 0.3550, Recon Loss: -2.7516, KL Loss: 3.1067
# Idx : 33, Total Loss: 0.3282, Recon Loss: -2.7880, KL Loss: 3.1162
# Idx : 89, Total Loss: 1.2411, Recon Loss: -2.5879, KL Loss: 3.8291
# Idx : 95, Total Loss: 0.3396, Recon Loss: -2.8020, KL Loss: 3.1416
# Idx : 86, Total Loss: 0.3285, Recon Loss: -2.8027, KL Loss: 3.1312
# Idx : 90, Total Loss: 0.3534, Recon Loss: -2.7813, KL Loss: 3.1347
# Idx : 25, Total Loss: 0.3334, Recon Loss: -2.8187, KL Loss: 3.1522
# Idx : 9, Total Loss: 0.3206, Recon Loss: -2.8396, KL Loss: 3.1602
# Idx : 57, Total Loss: 0.5272, Recon Loss: -2.6914, KL Loss: 3.2186
# Idx : 78, Total Loss: 1.2371, Recon Loss: -2.5546, KL Loss: 3.7917
# Idx : 0, Total Loss: 0.3399, Recon Loss: -2.7517, KL Loss: 3.0916
# Idx : 49, Total Loss: 1.2194, Recon Loss: -2.7267, KL Loss: 3.9461
# Idx : 18, Total Loss: 1.2188, Recon Loss: -2.6987, KL Loss: 3.9176
# Idx : 4, Total Loss: 0.3470, Recon Loss: -2.8014, KL Loss: 3.1484
# Idx : 37, Total Loss: 0.5558, Recon Loss: -2.6498, KL Loss: 3.2056
# Idx : 1, Total Loss: 0.3477, Recon Loss: -2.7044, KL Loss: 3.0521
# Idx : 11, Total Loss: 0.3229, Recon Loss: -2.7991, KL Loss: 3.1220
# Idx : 12, Total Loss: 0.3358, Recon Loss: -2.7842, KL Loss: 3.1199
# Idx : 83, Total Loss: 0.3407, Recon Loss: -2.7937, KL Loss: 3.1344
# Idx : 97, Total Loss: 0.5248, Recon Loss: -2.7476, KL Loss: 3.2724
# Idx : 92, Total Loss: 0.3328, Recon Loss: -2.7829, KL Loss: 3.1157
# Idx : 40, Total Loss: 0.3443, Recon Loss: -2.7499, KL Loss: 3.0942
# Idx : 10, Total Loss: 0.3238, Recon Loss: -2.7885, KL Loss: 3.1122
# Idx : 58, Total Loss: 1.2200, Recon Loss: -2.7008, KL Loss: 3.9207
# Idx : 93, Total Loss: 0.3276, Recon Loss: -2.8572, KL Loss: 3.1848
# Idx : 26, Total Loss: 0.3200, Recon Loss: -2.8144, KL Loss: 3.1344
# Idx : 91, Total Loss: 0.3174, Recon Loss: -2.8416, KL Loss: 3.1590
# Idx : 96, Total Loss: 0.3387, Recon Loss: -2.7971, KL Loss: 3.1358
# Idx : 53, Total Loss: 0.3270, Recon Loss: -2.8723, KL Loss: 3.1993
# Idx : 50, Total Loss: 0.3315, Recon Loss: -2.7492, KL Loss: 3.0807
# Idx : 2, Total Loss: 0.3416, Recon Loss: -2.7375, KL Loss: 3.0790
# Idx : 42, Total Loss: 0.3378, Recon Loss: -2.8433, KL Loss: 3.1811
# Idx : 76, Total Loss: 0.3366, Recon Loss: -2.8007, KL Loss: 3.1373
# Idx : 74, Total Loss: 0.3174, Recon Loss: -2.8745, KL Loss: 3.1918
# Idx : 51, Total Loss: 0.3308, Recon Loss: -2.7742, KL Loss: 3.1050
# Idx : 36, Total Loss: 0.3281, Recon Loss: -2.8036, KL Loss: 3.1317
# Idx : 69, Total Loss: 1.2197, Recon Loss: -2.6810, KL Loss: 3.9007
# Idx : 72, Total Loss: 0.3324, Recon Loss: -2.8407, KL Loss: 3.1731
# Idx : 32, Total Loss: 0.3312, Recon Loss: -2.7840, KL Loss: 3.1152
# Idx : 41, Total Loss: 0.3382, Recon Loss: -2.7936, KL Loss: 3.1318
# Idx : 46, Total Loss: 0.3454, Recon Loss: -2.7362, KL Loss: 3.0816
# Idx : 82, Total Loss: 0.3243, Recon Loss: -2.8544, KL Loss: 3.1787
# Idx : 77, Total Loss: 0.5093, Recon Loss: -2.6473, KL Loss: 3.1566
# Idx : 59, Total Loss: 1.2291, Recon Loss: -2.6575, KL Loss: 3.8866

# %%
cvae_save_path = f"result/cvae_xm_norm/{model_type}/cvae_{model_type}_{dim_z}_{hidden_dims[0]}\
_{batch_size}_{bn_chunks}_{lr}_{beta}_{warmup_chunks}_chunk{num_chunks}.pt" # = save_path

cvae_result_path = f"result/cvae_xm_norm/{model_type}/cvae_{model_type}_{dim_z}_{hidden_dims[0]}\
_{batch_size}_{bn_chunks}_{lr}_{beta}_{warmup_chunks}_chunk{num_chunks}_{barr_type}_{opt_type}.pkl"

ckpt = torch.load(cvae_save_path, map_location=device, weights_only=False)

cvae = CVAE(
    dim_x=ckpt["dim_x"],
    dim_eta=ckpt["dim_eta"],
    dim_z=ckpt["dim_z"],
    hidden_dims=ckpt["hidden_dims"],
    use_bn=ckpt.get("use_bn", False),
).to(device)

state_dict = ckpt["model_state"]
if any(k.startswith("module.") for k in state_dict):
    state_dict = {k.replace("module.", "", 1): v for k, v in state_dict.items()}

cvae.load_state_dict(state_dict)
cvae.eval()

eta_raw = np.array(test_etas, dtype=np.float32)
eta_scaled = (eta_raw - ckpt["eta_min"]) / (ckpt["eta_max"] - ckpt["eta_min"] + 1e-8)
eta_t = torch.tensor(eta_scaled, dtype=torch.float32, device=device)

n_list = [1000, 10000, 100000]
n_repeats = 50
results = {n: [] for n in n_list}


for n in n_list:
    for _ in range(n_repeats):
        if barr_type == "barr":
            price = cvae.price_barrier(eta_t, B, K, r, T, opt_type, n)
        else:
            price = cvae.price_vanilla(eta_t, K, r, T, opt_type, n)
        results[n].append(price)

with open(cvae_result_path, "wb") as f:
    pickle.dump(results, f)

# %%
# 공용 그래프: CVAE inference 결과만 표시
n_list = [1000, 10000, 100000]
cvae_result_path = f"result/cvae_xm_norm/{model_type}/cvae_{model_type}_{dim_z}_{hidden_dims[0]}\
_{batch_size}_{bn_chunks}_{lr}_{beta}_{warmup_chunks}_chunk{num_chunks}_{barr_type}_{opt_type}.pkl"

with open(cvae_result_path, "rb") as f:
    results = pickle.load(f)

means = np.array([np.mean(results[n]) for n in n_list])
stds = np.array([np.std(results[n]) for n in n_list])
ci = 1.96 * stds

print("CVAE")
for n, mean, err in zip(n_list, means, ci):
    rel_err = (mean - bench_price) / (bench_price + 1e-12) * 100
    print(f"n={n:6d} | mean={mean:.8f} | 95% CI=±{err:.8f} | error={rel_err:+.2f}%")

plt.figure(figsize=(7, 4))
plt.axhline(bench_price, color="gray", linewidth=1.5, label="FDM")
plt.errorbar(
    range(len(n_list)), means,
    yerr=ci, fmt="o-", color="steelblue", capsize=5, label="CVAE (95% CI)",
)
plt.xticks(range(len(n_list)), ["1K", "10K", "100K"])
plt.xlabel("Number of CVAE samples")
plt.ylabel("Option price")
plt.title(f"{cvae_result_path}")
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# CVAE
# n=  1000 | mean=0.00543866 | 95% CI=±0.00136604 | error=-42.96%
# n= 10000 | mean=0.00545473 | 95% CI=±0.00040918 | error=-42.79%
# n=100000 | mean=0.00546286 | 95% CI=±0.00011379 | error=-42.71%
